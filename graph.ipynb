# %%
#read file
import pandas as pd
df=pd.read_csv(r"C:\Users\kanwalShahid\Desktop\datafolder\insurance1.csv",encoding="Latin1")
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   VehicleReg      id CustomerName  Premium  Package       AddonDate    Make  \
# 0        V66  509040          C66  34000.0  Insured  8/7/2018 17:18  Suzuki
# 1        V66  509041          C66  34000.0  Insured  8/7/2018 17:18  Suzuki
# 2        V66  509042          C66  34000.0  Insured  8/7/2018 17:18  Suzuki
# 3        V66  509043          C66  34000.0  Insured  8/7/2018 17:18  Suzuki
# 4        V66  509044          C66  34000.0  Insured  8/7/2018 17:18  Suzuki
#
#     Model      CC GearType                        ...                          \
# 0  2016.0  1300.0     Auto                        ...
# 1  2016.0  1300.0     Auto                        ...
# 2  2016.0  1300.0     Auto                        ...
# ...

# %%
#visulaiztion of premium by histogram
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv(r"C:\Users\kanwalShahid\Desktop\datafolder\insurance1.csv",encoding="Latin1")
num_bins = 50
plt.hist(df['Premium'], num_bins, normed=1, facecolor='pink', alpha=0.5)
plt.title("Premium histrogram")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df.columns
# Out:
# Index(['VehicleReg', 'id', 'CustomerName', 'Premium', 'Package', 'AddonDate',
#        'Make', 'Model', 'CC', 'GearType', 'Gender', 'Address', 'VehicleType',
#        'VehicleWidth', 'VehicleHeight', 'FuelType', 'BrakeOperation',
#        'AvgFuelConsumption', 'StatusText', 'Speed', 'Odo', 'AssembledDate',
#        'Place'],
#       dtype='object')

# %%
#describe give count,min,max
df.describe()
# Out:
#              Premium          Model             CC   VehicleWidth  \
# count  721349.000000  721349.000000  721349.000000  721349.000000
# mean    37356.128587    2016.249677    1383.903215       4.925994
# std      7473.891228       1.645820     186.847281       0.601491
# min     34000.000000    2013.000000    1300.000000       0.000000
# 25%     34000.000000    2016.000000    1300.000000       5.000000
# 50%     34000.000000    2017.000000    1300.000000       5.000000
# 75%     34000.000000    2017.000000    1300.000000       5.000000
# max     54000.000000    2018.000000    1800.000000       5.000000
#
#        VehicleHeight  AvgFuelConsumption          Speed            Odo
# count  721349.000000       721349.000000  721349.000000  721349.000000
# mean        2.956149           10.987385      25.064187     424.733925
# std         0.360043            0.224886      27.996123     380.675316
# min         0.000000            8.000000       0.000000       0.000000
# ...

# %%
#BOX PLOT of Package Vs premium
import matplotlib.pyplot as plt
import pandas as pd
df.boxplot(column='Premium', by = 'Package' ,rot = 30, figsize=(5,6))
plt.ylabel("Premium")
plt.title("Package vs Premium")
plt.show()

# %%
#BOX PLOT of Geartype Vs premium
import matplotlib.pyplot as plt
import pandas as pd
df.boxplot(column='Premium', by = 'GearType' ,rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("GearType vs Premium")
plt.show()

# %%
#BOX PLOT of CC Vs premium
df.boxplot(column='CC', by = 'Premium', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("CC vs Premium")
plt.show()

# %%
#BOX PLOT of Model Vs premium

df.boxplot(column='Model', by = 'Premium',rot=30,figsize=(5,6))
plt.ylabel("Premium")
plt.title("Model vs Premium")
plt.show()

# %%
#BOX PLOT of  Make Vs premium
df.boxplot(column='Premium', by = 'Make',rot=30,figsize=(5,6))
plt.ylabel("Premium")
plt.title("Make vs Premium")
plt.show()

# %%
#BOX PLOT of  Gender Vs premium

df.boxplot(column='Premium', by = 'Gender', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("Gender vs Premium")
plt.show()

# %%
#BOX PLOT Address Vs premium

df.boxplot(column='Premium', by = 'Address', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("Address vs Premium")
plt.show()

# %%
#BOX PLOT of VehicleType  Vs premium

df.boxplot(column='Premium', by = 'VehicleType', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("VehicleType vs Premium")
plt.show()

# %%
#BOX PLOT of VehicleWidthVs premium

import matplotlib.pyplot as plt
df.boxplot(column='VehicleWidth', by = 'Premium', rot = 30,  figsize=(5,6))

plt.title("VehicleWidth vs Premium")
plt.show()
#BOX PLOT of VehicleWidthVs premium
df.boxplot(column='Premium', by = 'VehicleWidth', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("VehicleWidth vs Premium")
plt.show()

# %%
#BOX PLOT of FuelType Vs premium
df.boxplot(column='Premium', by = 'FuelType', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("FuelType vs Premium")
plt.show()

# %%
#BOX PLOT of BrakeOperation Vs premium
df.boxplot(column='Premium', by = 'BrakeOperation', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("BrakeOperation vs Premium")
plt.show()

# %%
#BOX PLOT of AvgFuelConsumption Vs premium
import matplotlib.pyplot as plt
df.boxplot(column='Premium', by = 'AvgFuelConsumption', rot = 30,  figsize=(5,6))
plt.ylabel("Premium")
plt.title("AvgFuelConsumption vs Premium")
plt.show()
